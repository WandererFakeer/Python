# %% [markdown]
# <a href="https://www.kaggle.com/code/wandererfakeer/100-days-of-code-day-4-rock-paper-scissors-game?scriptVersionId=188856222" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
rock_ascii = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper_ascii = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors_ascii = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

# %%
import random

# %%
game_options = ["rock", "paper", "scissors"]

user_score = computer_score = 0

# %%
def graphic (user, who):
    
    """
            This function takes user choice and who (computer or user) as 2 parameters,
            and prints the choices, according to the user or computer,
            with values from the ascii arts

    """

    if (user == game_options[0]):

        print(f"{who} chose: {rock_ascii}")

    elif (user == game_options[1]):

        print(f"{who} chose: {paper_ascii}")
        
    elif (user == game_options[2]):

        print(f"{who} chose: {scissors_ascii}")

    else:
        print(f"{who} chose wrong option. Choose correct option again")

# %%
def result (user_result, computer_result):
    """
        This function takes user choice and computer random choice, as 2 parameters, and
        checks the wining conditions, with "If-elif"

    """

    if (user_result == computer_result):

        print("Draw")

    elif ((user_result == "rock" and computer_result == "scissors") or
        (user_result == "paper" and computer_result == "rock") or
        (user_result == "scissors" and computer_result == "paper")):
        
        global user_score
        
        user_score += 1

        print("You win!")

    elif ((user_result == "rock" and computer_result == "paper") or
        (user_result == "paper" and computer_result == "scissors") or
        (user_result == "scissors" and computer_result == "rock")):
        
        global computer_score
        
        computer_score += 1

        print("You lose!")
        
    else:
        print(f"You entered {user_result}. It's an invalid entry")

# %%
def the_game ():

    user_choice = input('What do you choose? Type "Rock", "Paper" or "Scissors":\n').lower()

    graphic(user_choice, "You")
    
    if user_choice in game_options:

        computer_choice = random.choice(game_options).lower()

        graphic(computer_choice, "Computer")
    

        result(user_choice, computer_choice)

# %%
while True:

    the_game()

    continuity = input('Do you want to play again? Type "Yes" or "No". ').lower()

    if (continuity == "no"):
        
        print(f"Your score: {user_score}")
        
        print(f"Computer's score: {computer_score}")

        break
# Out:
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Draw
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  r
# You chose wrong option
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# You lose!
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  paper
# You chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Draw
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  scissors
# You chose:
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# You lose!
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# You win!
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  paper
# You chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# You lose!
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  ro
# You chose wrong option
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Draw
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# You win!
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Draw
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  paper
# You chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Draw
# Do you want to play again? Type "Yes" or "No".  yes
# What do you choose? Type "Rock", "Paper" or "Scissors":
#  rock
# You chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer chose:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# You lose!
# Do you want to play again? Type "Yes" or "No".  no
# Your score: 2
# Computer's score: 4
